# %%
/pwd
# Out:
# '/content'

# %%
ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jan 11 17:02 ./
# drwxr-xr-x 1 root root 4096 Jan 15 05:34 ../
# drwxr-xr-x 4 root root 4096 Jan 11 17:01 .config/
# drwxr-xr-x 1 root root 4096 Jan 11 17:02 sample_data/

# %%
cd ..
# Out:
# /

# %%
ls -al
# Out:
# total 112
# drwxr-xr-x   1 root root  4096 Jan 15 05:34 ./
# drwxr-xr-x   1 root root  4096 Jan 15 05:34 ../
# lrwxrwxrwx   1 root root     7 Oct  4 02:08 bin -> usr/bin/
# drwxr-xr-x   2 root root  4096 Apr 18  2022 boot/
# drwxr-xr-x   1 root root  4096 Jan 11 17:02 content/
# -rw-r--r--   1 root root  4332 Nov 10 04:56 cuda-keyring_1.0-1_all.deb
# drwxr-xr-x   1 root root  4096 Jan 11 17:20 datalab/
# drwxr-xr-x   5 root root   360 Jan 15 05:34 dev/
# -rwxr-xr-x   1 root root     0 Jan 15 05:34 .dockerenv*
# drwxr-xr-x   1 root root  4096 Jan 15 05:34 etc/
# drwxr-xr-x   2 root root  4096 Apr 18  2022 home/
# lrwxrwxrwx   1 root root     7 Oct  4 02:08 lib -> usr/lib/
# lrwxrwxrwx   1 root root     9 Oct  4 02:08 lib32 -> usr/lib32/
# lrwxrwxrwx   1 root root     9 Oct  4 02:08 lib64 -> usr/lib64/
# lrwxrwxrwx   1 root root    10 Oct  4 02:08 libx32 -> usr/libx32/
# drwxr-xr-x   2 root root  4096 Oct  4 02:08 media/
# drwxr-xr-x   2 root root  4096 Oct  4 02:08 mnt/
# ...

# %%
cd content
# Out:
# /content

# %%
ls -al
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jan 11 17:02 ./
# drwxr-xr-x 1 root root 4096 Jan 15 05:34 ../
# drwxr-xr-x 4 root root 4096 Jan 11 17:01 .config/
# drwxr-xr-x 1 root root 4096 Jan 11 17:02 sample_data/

# %%
cd drive
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content
